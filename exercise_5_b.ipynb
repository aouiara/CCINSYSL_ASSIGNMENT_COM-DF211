# %% [markdown]
# <a href="https://colab.research.google.com/github/aouiara/CCINSYSL_ASSIGNMENT_COM-DF211/blob/main/exercise_5_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 5 B

# %%
import numpy as np
from sklearn.datasets import fetch_olivetti_faces
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# %%
faces = fetch_olivetti_faces()

# %%
faces.data.shape
# Out:
# (400, 4096)

# %%
faces.images.shape
# Out:
# (400, 64, 64)

# %%
faces.target.shape
# Out:
# (400,)

# %%
faces.target[200]
# Out:
# 20

# %% [markdown]
# #### 1. Plot the image of index zero

# %%
plt.figure()
plt.imshow(faces.images[0], cmap='ocean')
plt.title('Image of Index 0', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Image of Index 0')

# %% [markdown]
# #### 2. Create a subplot of 10 images in a 3x3 configuration

# %%
fig, axes = plt.subplots(3, 3, figsize=(8, 8))
for i in range(9):
  ax = axes[i // 3, i % 3]
  ax.imshow(faces.images[i], cmap='cubehelix')
  ax.set_title(f"Image {i}")
  ax.axis('off')
plt.show()

# %% [markdown]
# #### 3. Split the data into a training and test set

# %%
from sklearn.model_selection import train_test_split
train_img, test_img, train_lbl, test_lbl = train_test_split(
    faces.data, faces.target, test_size=1/7.0, random_state=0)

# %% [markdown]
# #### 4. Create a new instance of the LogisticRegression class

# %%
LogisticReg = LogisticRegression()

# %% [markdown]
# #### 5. Train the model using the training set using the `fit()` function

# %%
LogisticReg.fit(train_img, train_lbl)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# #### 6. Use the test data to test the model using the `predict()` function

# %%
predictions = LogisticReg.predict(test_img)

# %% [markdown]
# #### 7. Get the accuracy using the `score()` function

# %%
score = LogisticReg.score(test_img, test_lbl)
score
# Out:
# 0.9655172413793104

# %% [markdown]
# #### 8. Collect all the misclassified images and create a plot for visualization

# %%
index = 0
misclassifiedIndexes = []
for label, predict in zip(test_lbl, predictions):
    if label != predict:
        misclassifiedIndexes.append(index)
    index +=1

plt.figure(figsize=(20,4))
for plotIndex, badIndex in enumerate(misclassifiedIndexes[0:5]):
    plt.subplot(1, 5, plotIndex + 1)
    plt.imshow(np.reshape(test_img[badIndex], (64,64)), cmap='inferno')
    plt.title('Predicted: {}, Actual: {}'.format(predictions[badIndex], test_lbl[badIndex]), fontsize = 15)

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# #### 9. Use the `SGDClassifier()` to use gradient descent to minimize the loss

# %%
clf = SGDClassifier(loss="log_loss", penalty="l2")

# %% [markdown]
# #### 10. Train the model using the training set using the `fit()` function

# %%
clf.fit(train_img, train_lbl)
# Out:
# SGDClassifier(loss='log_loss')

# %% [markdown]
# #### 11. Use the test data to test the model using the `predict()` function

# %%
y_pred = clf.predict(test_img)

# %% [markdown]
# #### 12. Get the accuracy using the `score()` function

# %%
clf.score(test_img, test_lbl)
# Out:
# 0.7931034482758621

# %% [markdown]
# #### 13. Find the best number of iterations to get the best accuracy

# %%
num_iter = [500, 600, 700]
scores = []

for i in num_iter:
  clf = SGDClassifier(loss="log_loss", penalty="l2", max_iter = i)
  clf.fit(train_img, train_lbl)
  y_pred = clf.predict(test_img)
  score = clf.score(test_img, test_lbl)
  scores.append(score)
  print(score)

plt.plot(num_iter, scores)
# Out:
# 0.7758620689655172
# 0.896551724137931
# 0.9137931034482759
